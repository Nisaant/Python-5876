# %% [markdown]
# ## Youhoooo

# %%
purse = dict()
purse['money'] = 12
purse['candy'] = 3
purse['tissues'] = 75
print(purse)
purse['candy'] = purse['candy']+2
print(purse)
# Out:
# {'money': 12, 'candy': 3, 'tissues': 75}
# {'money': 12, 'candy': 5, 'tissues': 75}

# %%
lst = list()
lst.append(21)
print(lst)
# Out:
# [21]

# %%
import numpy
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
x = random.normal(size=1000)
x = random.normal(size=(2,3))
x = random.normal(loc=1,scale=2,size=(2,3))
print(x)
sns.distplot(random.normal(size=1000),hist=False)
plt.show()
# Out:
# [[-0.6211838  -2.1270873   1.8840019 ]
#  [ 0.48669924  0.16102165 -0.39329915]]
# C:\Users\kotha\AppData\Local\Temp\ipykernel_2052\2557508689.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000),hist=False)

# %%
from numpy import random
x=random.binomial(n=10,p=0.5,size=1000)
print (x)
# Out:
# [4 6 3 5 7 7 7 8 2 4 4 6 6 8 9 5 3 3 4 4 6 3 4 4 7 4 4 5 6 8 5 4 5 5 7 6 8
#  5 5 2 5 5 3 3 5 6 6 6 4 6 5 7 7 2 5 5 3 6 5 6 4 5 5 7 4 5 3 5 6 5 8 5 7 5
#  7 5 6 4 5 4 5 5 3 8 7 3 6 4 6 7 7 3 5 4 7 5 3 3 4 5 2 8 7 7 5 6 8 6 5 5 6
#  4 5 4 4 6 5 5 2 3 3 4 3 5 5 3 5 7 5 7 6 6 5 3 5 3 6 4 7 5 3 4 4 7 4 7 3 2
#  5 7 6 6 5 4 4 6 5 3 5 2 7 4 4 6 6 6 3 8 5 5 6 5 6 5 6 6 4 6 5 3 4 7 6 5 5
#  5 2 8 3 4 6 3 6 6 5 5 2 4 6 6 5 3 5 4 4 7 5 5 5 4 5 8 4 4 3 4 6 3 6 6 1 6
#  7 7 3 5 4 5 4 4 4 6 5 6 3 4 6 5 7 5 4 7 3 3 6 4 5 5 6 7 6 5 5 7 6 6 5 5 2
#  7 6 5 4 5 5 4 2 8 4 7 5 4 4 7 5 4 7 4 4 8 5 4 6 7 6 7 3 8 8 6 6 5 3 4 7 5
#  7 3 6 6 4 5 5 5 5 6 6 5 2 3 4 7 4 5 4 3 6 4 6 5 6 6 4 7 6 6 5 6 5 4 4 4 5
#  4 6 7 4 4 3 3 4 3 3 7 5 8 7 3 7 7 8 4 3 5 6 7 6 6 5 8 5 2 5 7 3 5 7 4 4 3
#  8 5 4 3 6 4 5 7 5 5 4 6 5 5 5 6 4 7 5 7 5 6 4 2 3 5 7 5 3 6 4 3 4 6 6 4 2
#  5 3 6 5 3 7 6 3 6 4 5 6 4 7 4 4 4 5 4 4 3 4 5 5 9 4 4 5 6 5 4 3 3 6 4 6 5
#  9 7 7 5 6 4 3 5 4 6 5 5 5 4 5 4 7 3 2 4 5 8 7 7 5 5 1 4 6 5 7 4 6 5 5 7 6
#  7 6 4 5 3 5 6 5 4 5 4 5 5 4 4 4 5 7 5 5 6 5 4 7 2 5 3 1 5 5 5 4 2 5 7 3 7
#  6 8 6 7 4 3 2 4 4 5 5 5 7 4 5 5 5 4 6 5 4 4 4 6 5 3 4 6 5 6 4 5 6 2 5 3 7
#  4 4 6 4 6 4 6 7 6 7 4 4 5 3 5 6 5 6 6 4 7 3 4 6 3 7 6 7 5 5 5 8 6 3 5 3 4
#  4 5 5 6 5 5 7 4 4 6 4 6 5 2 4 7 6 4 6 1 4 5 1 7 2 2 5 6 4 3 4 5 7 6 4 5 7
#  3 5 6 4 4 7 4 7 6 6 4 4 3 4 7 6 4 4 6 8 3 4 6 5 1 8 5 4 5 6 4 3 6 6 6 9 5
#  3 4 4 4 7 6 6 7 7 5 5 5 7 4 4 8 5 4 4 6 6 4 3 4 6 3 6 5 5 7 4 4 3 5 6 4 4
#  3 6 7 4 4 5 6 6 3 6 6 5 6 4 6 6 7 7 2 6 5 6 7 7 6 3 5 5 9 6 4 5 4 3 3 2 7
#  3 3 5 6 5 5 5 5 5 2 4 5 5 8 6 6 3 4 2 4 7 4 3 6 4 6 4 7 4 4 7 4 4 3 3 6 5
#  4 6 7 7 7 4 6 6 5 2 2 5 6 4 4 7 3 6 4 4 5 6 5 5 4 3 6 6 3 5 3 5 5 7 6 5 7
#  5 6 5 6 8 2 2 9 5 5 4 4 4 7 5 5 6 1 3 6 3 5 7 7 5 4 6 6 5 3 4 6 7 3 5 7 4
#  4 7 5 6 7 4 2 5 6 5 6 5 2 4 2 6 6 4 3 3 4 5 6 4 4 8 3 2 6 6 4 3 2 4 4 3 7
#  5 5 8 6 4 6 4 4 6 8 8 3 6 4 6 5 5 7 4 5 4 2 4 6 6 3 6 6 5 6 6 6 5 5 4 7 6
#  4 5 4 4 5 7 5 6 7 4 8 1 7 5 4 7 2 5 9 6 5 2 6 6 6 5 5 5 8 5 4 5 3 6 4 6 4
#  6 4 5 3 4 8 4 5 5 7 6 2 8 5 4 2 4 2 3 4 5 4 7 4 9 2 3 5 2 3 5 5 3 5 5 3 2
#  3]

# %%
from numpy import random 
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.binomial(n=10,p=0.5,size=1000),hist=True,kde=False)
plt.show()
# Out:
# C:\Users\kotha\AppData\Local\Temp\ipykernel_18356\3962762638.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=10,p=0.5,size=1000),hist=True,kde=False)

# %%
from numpy import random
x = random.poisson(lam=2,size=10)
print(x)
# Out:
# [2 3 0 1 0 2 2 3 1 1]

# %%
from numpy import random 
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.poisson(lam=2,size=1000),kde=False)
plt.show()
# Out:
# C:\Users\kotha\AppData\Local\Temp\ipykernel_18356\2661948511.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.poisson(lam=2,size=1000),kde=False)

# %%
import pandas as pd 
print(pd.__version__)
mydataset={
    'cars':["BMW","Volvo","Ford"],
    'passings':[3,7,2]
}
myvar=pd.DataFrame(mydataset)
print(myvar)
# Out:
# 2.3.1
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
import pandas as pd
calories={"day1":420,"day2":380,"day3":390}
myvar=pd.Series(calories)
print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
counts = dict()
total=0
print("Enter a line:")
line = input("Line: ")
words = line.split()
word_length=len(words)
print("Words in the word:")
print("counting....",word_length)

for word in words:
    counts[word] = counts.get(word, 0) + 1
    
    if word.isdigit():
        total += int(word)
        
       # print(word, counts [word])
for ch in word:
        if ch.isdigit():
            num += ch
        elif not ch.isalnum():
            specials.append(ch)
if specials:
           print("Special symbols were present.")
           print("Special Symbols:", specials)
else:
    print("No special symbols found.")
print("Counting complete")
print("Sum of all numbers",total)
print("Concatinated String Numbers ",concat)
# Out:
# Enter a line:
# Line:  Hello Sir 123 @@@ 456
# Words in the word:
# counting.... 5
# Special symbols were present.
# Special Symbols: ['@', '#', '$']
# Counting complete
# Sum of all numbers 579
# Concatinated String Numbers  HelloSir123@@@456123456123456

# %%
counts = dict()
total = 0
concat = ""
num = ""
specials = []

print("Enter a line:")
line = input("Line: ")

words = line.split()
word_length = len(words)

print("Words in the line:")
print("Counting....", word_length)

for word in words:
    counts[word] = counts.get(word, 0) + 1
    
    if word.isdigit():
        total += int(word)
        concat += word
    
    for ch in word:
        if ch.isdigit():
            num += ch
        elif not ch.isalnum():
            specials.append(ch)

if specials:
    print("Special symbols were present.")
    print("Special Symbols:", specials)
else:
    print("No special symbols found.")

print("Counting complete")
print("Sum of all numbers:", total)
print("Concatenated String Numbers:", concat)
# Out:
# Enter a line:
# Line:  Hello Sir 123 @@@ 456
# Words in the line:
# Counting.... 5
# Special symbols were present.
# Special Symbols: ['@', '@', '@']
# Counting complete
# Sum of all numbers: 579
# Concatenated String Numbers: 123456
